# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = "./DataSet/train.p"
validation_file ="./DataSet/valid.p"
testing_file = "./DataSet/test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value.
### Use python, pandas or numpy methods rather than hard coding the results

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of validation examples
n_validation = X_valid.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(set(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline
keys = set(y_train)
train_stats = {key:0 for key in keys}
valid_stats = train_stats.copy()
test_stats = train_stats.copy()
for y in y_train:
    train_stats[y]+=1
for y in y_test:
    test_stats[y]+=1
for y in y_valid:
    valid_stats[y]+=1
f, arrx = plt.subplots(3, sharex=True)
arrx[0].plot(*zip(*sorted(train_stats.items())))
arrx[0].set_title('Statistics of Train Data')
arrx[1].plot(*zip(*sorted(valid_stats.items())))
arrx[1].set_title('Statistics of Validation Data')
arrx[2].plot(*zip(*sorted(test_stats.items())))
arrx[2].set_title('Statistics of Test Data')
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.
import numpy as np
def rgb2gray(im):
    im = np.dot(im[..., :3], [0.299, 0.587, 0.114])
    im = im[:,:,:,None]
    return im
X_train = rgb2gray(X_train)
X_valid = rgb2gray(X_valid)
X_test = rgb2gray(X_test)
X_train=(X_train-128)/128
X_valid=(X_valid-128)/128
X_test=(X_test-128)/128

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.
import tensorflow as tf
def leNet(X, keep_prob):
    mu=0
    std = 0.1
    #convolution layer
    my_filter = tf.Variable(tf.truncated_normal((5,5,1,6), mean=mu, stddev= std))
    layer = tf.nn.conv2d(X,my_filter,[1,1,1,1],'VALID')
    layer = tf.nn.relu(layer)
    #output dimensions: 28*28*6

    #max pooling layer
    layer = tf.nn.max_pool(layer,[1,2,2,1],[1,2,2,1],'VALID')
    #output dimensions: 14*14*6

    my_filter = tf.Variable(tf.truncated_normal((5,5,6,16), mean=mu, stddev= std))
    layer = tf.nn.conv2d(layer,my_filter,[1,1,1,1],'VALID')
    layer = tf.nn.relu(layer)
    #output dimensions: 10*10*16
    layer = tf.nn.max_pool(layer,[1,2,2,1],[1,2,2,1], 'VALID')
    #output dimensions: 5*5*16
    layer = tf.contrib.layers.flatten(layer)
    #output dimensions: 400
    weight1=tf.Variable(tf.truncated_normal((400,120), mean=mu, stddev= std))
    bias1=tf.Variable(tf.zeros(120))
    layer=tf.add(tf.matmul(layer,weight1),bias1)
    layer=tf.nn.relu(layer)
    #output dimensions: 120
    layer=tf.nn.dropout(layer,keep_prob)
    weight2=tf.Variable(tf.truncated_normal((120,84), mean=mu, stddev= std))
    bias2=tf.Variable(tf.zeros(84))
    layer=tf.add(tf.matmul(layer,weight2),bias2)
    layer=tf.nn.relu(layer)
    layer=tf.nn.dropout(layer,keep_prob)
    #output dimensions: 84
    weight3=tf.Variable(tf.truncated_normal((84,43), mean=mu, stddev= std))
    bias3=tf.Variable(tf.zeros(43))
    logits=tf.add(tf.matmul(layer,weight3),bias3)
    return logits

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
from sklearn.utils import shuffle
x = tf.placeholder(tf.float32, (None,32,32,1))
y = tf.placeholder(tf.int32, (None))
one_hot = tf.one_hot(y,43)
keep_prob = tf.placeholder(tf.float32)

learning_rate=0.002
#batch_size=34000
epochs=600
logits = leNet(x, keep_prob)
probabilities=tf.nn.softmax(logits)
cross_entropy =tf.nn.softmax_cross_entropy_with_logits(labels=one_hot,logits=logits)
loss = tf.reduce_mean(cross_entropy)
optimizer=tf.train.AdamOptimizer(learning_rate)
training_operation= optimizer.minimize(loss)
accuracy_operation= tf.reduce_mean(tf.cast(tf.equal(tf.argmax(one_hot,1),tf.argmax(logits,1)),tf.float32))
selected_class=tf.argmax(probabilities,1)
top_5 = tf.nn.top_k(probabilities,k=5)

def evaluate_accuracy(xIn, yIn):
    sess = tf.get_default_session()
    # accuracy = 0
    # den = 0
    # start_index=0
    # for start_index in range(0, len(xIn)-batch_size, batch_size):
    #     batch_x=xIn[start_index:start_index+batch_size]
    #     batch_y=yIn[start_index:start_index+batch_size]
    #     accuracy+= batch_size * sess.run(accuracy_operation, feed_dict={x:batch_x, y:batch_y, keep_prob:1})
    #     den+=batch_size
    # if start_index==0:
    #     accuracy+=len(xIn)* sess.run(accuracy_operation, feed_dict={x:xIn, y:yIn, keep_prob:1})
    #     den+=len(xIn)
    # else:
    #     batch_x=xIn[start_index+batch_size:]
    #     batch_y=yIn[start_index+batch_size:]
    #     accuracy += (len(xIn)-start_index-batch_size) * sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 1})
    #     den += len(xIn)-start_index-batch_size
    # return accuracy/den
    return sess.run(accuracy_operation,feed_dict={x:xIn,y:yIn,keep_prob:1})

saver = tf.train.Saver()
model_file="./final_model.ckpt"

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        print(i)
        X_train, y_train = shuffle(X_train,y_train)
        # for start_index in range(0,n_train-batch_size,batch_size):
        #     end_index=start_index+batch_size
        #     batch_x = X_train[start_index:end_index]
        #     batch_y = y_train[start_index:end_index]
        #     sess.run(training_operation,feed_dict={x:batch_x,y:batch_y, keep_prob:0.4})
        # start_index = end_index
        # batch_x = X_train[start_index:]
        # batch_y = y_train[start_index:]
        # sess.run(training_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 0.4})
        sess.run(training_operation,feed_dict={x:X_train,y:y_train,keep_prob:0.4})
        accuracy = evaluate_accuracy(X_train,y_train)
        print("The accuracy of the training data is {}".format(accuracy))
    accuracy = evaluate_accuracy(X_valid, y_valid)
    print("The accuracy of the validation set is {}".format(accuracy))
    accuracy = evaluate_accuracy(X_test, y_test)
    print("The accuracy of the test set is {}".format(accuracy))
    saver.save(sess,model_file)
# Out:
# 0
# The accuracy of the training data is 0.056237246841192245
# 1
# The accuracy of the training data is 0.06330641359090805
# 2
# The accuracy of the training data is 0.06592143326997757
# 3
# The accuracy of the training data is 0.06646742671728134
# 4
# The accuracy of the training data is 0.06727204471826553
# 5
# The accuracy of the training data is 0.07224345207214355
# 6
# The accuracy of the training data is 0.07905399799346924
# 7
# The accuracy of the training data is 0.08586453646421432
# 8
# The accuracy of the training data is 0.09238771349191666
# 9
# The accuracy of the training data is 0.09727291017770767
# 10
# The accuracy of the training data is 0.10075002163648605
# 11
# The accuracy of the training data is 0.10623868554830551
# 12
# The accuracy of the training data is 0.10974453389644623
# 13
# The accuracy of the training data is 0.11779074370861053
# 14
# The accuracy of the training data is 0.1313256174325943
# 15
# The accuracy of the training data is 0.14592373371124268
# 16
# The accuracy of the training data is 0.16264835000038147
# 17
# The accuracy of the training data is 0.17399924993515015
# 18
# The accuracy of the training data is 0.18399953842163086
# 19
# The accuracy of the training data is 0.19319520890712738
# 20
# The accuracy of the training data is 0.2052357792854309
# 21
# The accuracy of the training data is 0.22029368579387665
# 22
# The accuracy of the training data is 0.23523664474487305
# 23
# The accuracy of the training data is 0.24586912989616394
# 24
# The accuracy of the training data is 0.25463375449180603
# 25
# The accuracy of the training data is 0.2675364315509796
# 26
# The accuracy of the training data is 0.28219202160835266
# 27
# The accuracy of the training data is 0.29193368554115295
# 28
# The accuracy of the training data is 0.30679041147232056
# 29
# The accuracy of the training data is 0.3235725164413452
# 30
# The accuracy of the training data is 0.33472225069999695
# 31
# The accuracy of the training data is 0.35325726866722107
# 32
# The accuracy of the training data is 0.36567142605781555
# 33
# The accuracy of the training data is 0.3829995095729828
# 34
# The accuracy of the training data is 0.39719530940055847
# 35
# The accuracy of the training data is 0.41400614380836487
# 36
# The accuracy of the training data is 0.4309893846511841
# 37
# The accuracy of the training data is 0.4480013847351074
# 38
# The accuracy of the training data is 0.44461047649383545
# 39
# The accuracy of the training data is 0.4759044945240021
# 40
# The accuracy of the training data is 0.45768555998802185
# 41
# The accuracy of the training data is 0.48010000586509705
# 42
# The accuracy of the training data is 0.5075433254241943
# 43
# The accuracy of the training data is 0.5048421025276184
# 44
# The accuracy of the training data is 0.48918071389198303
# 45
# The accuracy of the training data is 0.5009914040565491
# 46
# The accuracy of the training data is 0.5280324220657349
# 47
# The accuracy of the training data is 0.5379752516746521
# 48
# The accuracy of the training data is 0.5346418023109436
# 49
# The accuracy of the training data is 0.5352740287780762
# 50
# The accuracy of the training data is 0.5568550825119019
# 51
# The accuracy of the training data is 0.5658783316612244
# 52
# The accuracy of the training data is 0.5682922005653381
# 53
# The accuracy of the training data is 0.5757061839103699
# 54
# The accuracy of the training data is 0.5946722626686096
# 55
# The accuracy of the training data is 0.6050748825073242
# 56
# The accuracy of the training data is 0.6161958575248718
# 57
# The accuracy of the training data is 0.6217420101165771
# 58
# The accuracy of the training data is 0.6342710852622986
# 59
# The accuracy of the training data is 0.6417138576507568
# 60
# The accuracy of the training data is 0.6462254524230957
# 61
# The accuracy of the training data is 0.6488404870033264
# 62
# The accuracy of the training data is 0.6621454358100891
# 63
# The accuracy of the training data is 0.6686111688613892
# 64
# The accuracy of the training data is 0.6775194406509399
# 65
# The accuracy of the training data is 0.6835828423500061
# 66
# The accuracy of the training data is 0.6908244490623474
# 67
# The accuracy of the training data is 0.6962843537330627
# 68
# The accuracy of the training data is 0.6972326636314392
# 69
# The accuracy of the training data is 0.7064858078956604
# 70
# The accuracy of the training data is 0.7151067852973938
# 71
# The accuracy of the training data is 0.7145320177078247
# 72
# The accuracy of the training data is 0.7177504897117615
# 73
# The accuracy of the training data is 0.733153223991394
# 74
# The accuracy of the training data is 0.7403661012649536
# 75
# The accuracy of the training data is 0.735049843788147
# 76
# The accuracy of the training data is 0.7400500178337097
# 77
# The accuracy of the training data is 0.7507399916648865
# 78
# The accuracy of the training data is 0.752406656742096
# 79
# The accuracy of the training data is 0.7551366686820984
# 80
# The accuracy of the training data is 0.7662001848220825
# 81
# The accuracy of the training data is 0.7672059535980225
# 82
# The accuracy of the training data is 0.767062246799469
# 83
# The accuracy of the training data is 0.7756257653236389
# 84
# The accuracy of the training data is 0.7794189453125
# 85
# The accuracy of the training data is 0.777723491191864
# 86
# The accuracy of the training data is 0.7883272767066956
# 87
# The accuracy of the training data is 0.793384850025177
# 88
# The accuracy of the training data is 0.7935285568237305
# 89
# The accuracy of the training data is 0.8035863041877747
# 90
# The accuracy of the training data is 0.8071496486663818
# 91
# The accuracy of the training data is 0.8075231909751892
# 92
# The accuracy of the training data is 0.8126095533370972
# 93
# The accuracy of the training data is 0.8190464973449707
# 94
# The accuracy of the training data is 0.8149659633636475
# 95
# The accuracy of the training data is 0.821287989616394
# 96
# The accuracy of the training data is 0.8305123448371887
# 97
# The accuracy of the training data is 0.829679012298584
# 98
# The accuracy of the training data is 0.8324376940727234
# 99
# The accuracy of the training data is 0.8388171792030334
# 100
# The accuracy of the training data is 0.8384436368942261
# 101
# The accuracy of the training data is 0.8393344879150391
# 102
# The accuracy of the training data is 0.8434725403785706
# 103
# The accuracy of the training data is 0.8460587859153748
# 104
# The accuracy of the training data is 0.8483577370643616
# 105
# The accuracy of the training data is 0.8513175845146179
# 106
# The accuracy of the training data is 0.8512888550758362
# 107
# The accuracy of the training data is 0.8554269075393677
# 108
# The accuracy of the training data is 0.8571510910987854
# 109
# The accuracy of the training data is 0.8581855893135071
# 110
# The accuracy of the training data is 0.8610305190086365
# 111
# The accuracy of the training data is 0.8639041185379028
# 112
# The accuracy of the training data is 0.8635880351066589
# 113
# The accuracy of the training data is 0.8692491054534912
# 114
# The accuracy of the training data is 0.8663179874420166
# 115
# The accuracy of the training data is 0.8708009123802185
# 116
# The accuracy of the training data is 0.8705134987831116
# 117
# The accuracy of the training data is 0.8726400136947632
# 118
# The accuracy of the training data is 0.8753412365913391
# 119
# The accuracy of the training data is 0.8736745119094849
# 120
# The accuracy of the training data is 0.8759160041809082
# 121
# The accuracy of the training data is 0.8784160614013672
# 122
# The accuracy of the training data is 0.8815770745277405
# 123
# The accuracy of the training data is 0.8823529481887817
# 124
# The accuracy of the training data is 0.8842782974243164
# 125
# The accuracy of the training data is 0.8890772461891174
# 126
# The accuracy of the training data is 0.8849679827690125
# 127
# The accuracy of the training data is 0.8884163498878479
# 128
# The accuracy of the training data is 0.8901692628860474
# 129
# The accuracy of the training data is 0.8876979351043701
# 130
# The accuracy of the training data is 0.889019787311554
# 131
# The accuracy of the training data is 0.8932728171348572
# 132
# The accuracy of the training data is 0.8916922807693481
# 133
# The accuracy of the training data is 0.8933302760124207
# 134
# The accuracy of the training data is 0.8963188529014587
# 135
# The accuracy of the training data is 0.8962039351463318
# 136
# The accuracy of the training data is 0.8948820233345032
# 137
# The accuracy of the training data is 0.8984166383743286
# 138
# The accuracy of the training data is 0.8983879089355469
# 139
# The accuracy of the training data is 0.8980143070220947
# 140
# The accuracy of the training data is 0.9036466479301453
# 141
# The accuracy of the training data is 0.9018937349319458
# 142
# The accuracy of the training data is 0.9014626741409302
# 143
# The accuracy of the training data is 0.9056869745254517
# 144
# The accuracy of the training data is 0.9044225215911865
# 145
# The accuracy of the training data is 0.905457079410553
# 146
# The accuracy of the training data is 0.9033018350601196
# 147
# The accuracy of the training data is 0.9068938493728638
# 148
# The accuracy of the training data is 0.907066285610199
# 149
# The accuracy of the training data is 0.907755970954895
# 150
# The accuracy of the training data is 0.910457193851471
# 151
# The accuracy of the training data is 0.9094801545143127
# 152
# The accuracy of the training data is 0.9108882546424866
# 153
# The accuracy of the training data is 0.9108307957649231
# 154
# The accuracy of the training data is 0.9122101068496704
# 155
# The accuracy of the training data is 0.9139918088912964
# 156
# The accuracy of the training data is 0.913646936416626
# 157
# The accuracy of the training data is 0.9128997921943665
# 158
# The accuracy of the training data is 0.9132446050643921
# 159
# The accuracy of the training data is 0.9152562022209167
# 160
# The accuracy of the training data is 0.9160608053207397
# 161
# The accuracy of the training data is 0.9160608053207397
# 162
# The accuracy of the training data is 0.9143078923225403
# 163
# The accuracy of the training data is 0.9191356301307678
# 164
# The accuracy of the training data is 0.9208885431289673
# 165
# The accuracy of the training data is 0.9175550937652588
# 166
# The accuracy of the training data is 0.9208310842514038
# 167
# The accuracy of the training data is 0.9187907576560974
# 168
# The accuracy of the training data is 0.9183596968650818
# 169
# The accuracy of the training data is 0.9218943119049072
# 170
# The accuracy of the training data is 0.9222391247749329
# 171
# The accuracy of the training data is 0.9227563738822937
# 172
# The accuracy of the training data is 0.9239633083343506
# 173
# The accuracy of the training data is 0.9271818399429321
# 174
# The accuracy of the training data is 0.9263484477996826
# 175
# The accuracy of the training data is 0.9262335300445557
# 176
# The accuracy of the training data is 0.9250265955924988
# 177
# The accuracy of the training data is 0.9256874918937683
# 178
# The accuracy of the training data is 0.9267507791519165
# 179
# The accuracy of the training data is 0.9269806742668152
# 180
# The accuracy of the training data is 0.9306302070617676
# 181
# The accuracy of the training data is 0.9316072463989258
# 182
# The accuracy of the training data is 0.9309462904930115
# 183
# The accuracy of the training data is 0.9323256611824036
# 184
# The accuracy of the training data is 0.9291359186172485
# 185
# The accuracy of the training data is 0.9303428530693054
# 186
# The accuracy of the training data is 0.9310324788093567
# 187
# The accuracy of the training data is 0.9339061379432678
# 188
# The accuracy of the training data is 0.9376131296157837
# 189
# The accuracy of the training data is 0.9370096921920776
# 190
# The accuracy of the training data is 0.9355728626251221
# 191
# The accuracy of the training data is 0.9362625479698181
# 192
# The accuracy of the training data is 0.9354579448699951
# 193
# The accuracy of the training data is 0.935774028301239
# 194
# The accuracy of the training data is 0.9353429675102234
# 195
# The accuracy of the training data is 0.9362338185310364
# 196
# The accuracy of the training data is 0.939854621887207
# 197
# The accuracy of the training data is 0.9407166838645935
# 198
# The accuracy of the training data is 0.9399120807647705
# 199
# The accuracy of the training data is 0.94166499376297
# 200
# The accuracy of the training data is 0.9423259496688843
# 201
# The accuracy of the training data is 0.9429006576538086
# 202
# The accuracy of the training data is 0.943360447883606
# 203
# The accuracy of the training data is 0.941463828086853
# 204
# The accuracy of the training data is 0.9390212297439575
# 205
# The accuracy of the training data is 0.9395959377288818
# 206
# The accuracy of the training data is 0.9417511820793152
# 207
# The accuracy of the training data is 0.9443662166595459
# 208
# The accuracy of the training data is 0.9472686052322388
# 209
# The accuracy of the training data is 0.947153627872467
# 210
# The accuracy of the training data is 0.9483892917633057
# 211
# The accuracy of the training data is 0.9488778710365295
# 212
# The accuracy of the training data is 0.9478720426559448
# 213
# The accuracy of the training data is 0.9463777542114258
# 214
# The accuracy of the training data is 0.9469525218009949
# 215
# The accuracy of the training data is 0.9464352130889893
# 216
# The accuracy of the training data is 0.9478720426559448
# 217
# The accuracy of the training data is 0.950544536113739
# 218
# The accuracy of the training data is 0.9520388245582581
# 219
# The accuracy of the training data is 0.9520963430404663
# 220
# The accuracy of the training data is 0.9512054920196533
# 221
# The accuracy of the training data is 0.9509755969047546
# 222
# The accuracy of the training data is 0.9509468674659729
# 223
# The accuracy of the training data is 0.9500272870063782
# 224
# The accuracy of the training data is 0.9517802000045776
# 225
# The accuracy of the training data is 0.952239990234375
# 226
# The accuracy of the training data is 0.9541653394699097
# 227
# The accuracy of the training data is 0.9544814229011536
# 228
# The accuracy of the training data is 0.9532457590103149
# 229
# The accuracy of the training data is 0.9528147578239441
# 230
# The accuracy of the training data is 0.9520963430404663
# 231
# The accuracy of the training data is 0.9512054920196533
# 232
# The accuracy of the training data is 0.9542803168296814
# 233
# The accuracy of the training data is 0.9564642906188965
# 234
# The accuracy of the training data is 0.9585620164871216
# 235
# The accuracy of the training data is 0.9586194753646851
# 236
# The accuracy of the training data is 0.9573838114738464
# 237
# The accuracy of the training data is 0.9571539163589478
# 238
# The accuracy of the training data is 0.956320583820343
# 239
# The accuracy of the training data is 0.95551598072052
# 240
# The accuracy of the training data is 0.9567803740501404
# 241
# The accuracy of the training data is 0.958217203617096
# 242
# The accuracy of the training data is 0.9587919116020203
# 243
# The accuracy of the training data is 0.9611770510673523
# 244
# The accuracy of the training data is 0.9614931344985962
# 245
# The accuracy of the training data is 0.9600850343704224
# 246
# The accuracy of the training data is 0.9600850343704224
# 247
# The accuracy of the training data is 0.9591655135154724
# 248
# The accuracy of the training data is 0.9583033919334412
# 249
# The accuracy of the training data is 0.9595965147018433
# 250
# The accuracy of the training data is 0.960602343082428
# 251
# The accuracy of the training data is 0.9610046148300171
# 252
# The accuracy of the training data is 0.9625851511955261
# 253
# The accuracy of the training data is 0.9618092179298401
# 254
# The accuracy of the training data is 0.9631598591804504
# 255
# The accuracy of the training data is 0.9634472131729126
# 256
# The accuracy of the training data is 0.9626713395118713
# 257
# The accuracy of the training data is 0.9625564217567444
# 258
# The accuracy of the training data is 0.96290123462677
# 259
# The accuracy of the training data is 0.9643380641937256
# 260
# The accuracy of the training data is 0.965286374092102
# 261
# The accuracy of the training data is 0.9642806053161621
# 262
# The accuracy of the training data is 0.9639931917190552
# 263
# The accuracy of the training data is 0.9644529819488525
# 264
# The accuracy of the training data is 0.9649127721786499
# 265
# The accuracy of the training data is 0.9653438329696655
# 266
# The accuracy of the training data is 0.965401291847229
# 267
# The accuracy of the training data is 0.9656599164009094
# 268
# The accuracy of the training data is 0.9660622477531433
# 269
# The accuracy of the training data is 0.9668668508529663
# 270
# The accuracy of the training data is 0.966981828212738
# 271
# The accuracy of the training data is 0.9664933085441589
# 272
# The accuracy of the training data is 0.9671254754066467
# 273
# The accuracy of the training data is 0.9668381214141846
# 274
# The accuracy of the training data is 0.9663496017456055
# 275
# The accuracy of the training data is 0.967987596988678
# 276
# The accuracy of the training data is 0.9684186577796936
# 277
# The accuracy of the training data is 0.9690508246421814
# 278
# The accuracy of the training data is 0.9701715707778931
# 279
# The accuracy of the training data is 0.9690508246421814
# 280
# The accuracy of the training data is 0.9684186577796936
# 281
# The accuracy of the training data is 0.968677282333374
# 282
# The accuracy of the training data is 0.9674990773200989
# 283
# The accuracy of the training data is 0.9693094491958618
# 284
# The accuracy of the training data is 0.9703439474105835
# 285
# The accuracy of the training data is 0.9700853228569031
# 286
# The accuracy of the training data is 0.9697117805480957
# 287
# The accuracy of the training data is 0.9704014658927917
# 288
# The accuracy of the training data is 0.9707175493240356
# 289
# The accuracy of the training data is 0.9708612561225891
# 290
# The accuracy of the training data is 0.9706026315689087
# 291
# The accuracy of the training data is 0.9717233180999756
# 292
# The accuracy of the training data is 0.9718957543373108
# 293
# The accuracy of the training data is 0.9710623621940613
# 294
# The accuracy of the training data is 0.9720394015312195
# 295
# The accuracy of the training data is 0.972068190574646
# 296
# The accuracy of the training data is 0.97129225730896
# 297
# The accuracy of the training data is 0.9721256494522095
# 298
# The accuracy of the training data is 0.9709187150001526
# 299
# The accuracy of the training data is 0.972671627998352
# 300
# The accuracy of the training data is 0.9737061262130737
# 301
# The accuracy of the training data is 0.9722405672073364
# 302
# The accuracy of the training data is 0.9737923741340637
# 303
# The accuracy of the training data is 0.9740509986877441
# 304
# The accuracy of the training data is 0.9724130034446716
# 305
# The accuracy of the training data is 0.9740797281265259
# 306
# The accuracy of the training data is 0.9742808938026428
# 307
# The accuracy of the training data is 0.9722980260848999
# 308
# The accuracy of the training data is 0.9750567674636841
# 309
# The accuracy of the training data is 0.9754015803337097
# 310
# The accuracy of the training data is 0.973677396774292
# 311
# The accuracy of the training data is 0.9747981429100037
# 312
# The accuracy of the training data is 0.9747981429100037
# 313
# The accuracy of the training data is 0.9737635850906372
# 314
# The accuracy of the training data is 0.976177453994751
# 315
# The accuracy of the training data is 0.9769245982170105
# 316
# The accuracy of the training data is 0.9760338068008423
# 317
# The accuracy of the training data is 0.9765797853469849
# 318
# The accuracy of the training data is 0.9765510559082031
# 319
# The accuracy of the training data is 0.9755740165710449
# 320
# The accuracy of the training data is 0.9757464528083801
# 321
# The accuracy of the training data is 0.9771544933319092
# 322
# The accuracy of the training data is 0.9771832227706909
# 323
# The accuracy of the training data is 0.9775568246841431
# 324
# The accuracy of the training data is 0.9779016375541687
# 325
# The accuracy of the training data is 0.9769245982170105
# 326
# The accuracy of the training data is 0.9770395755767822
# 327
# The accuracy of the training data is 0.9771832227706909
# 328
# The accuracy of the training data is 0.9774993658065796
# 329
# The accuracy of the training data is 0.9779878854751587
# 330
# The accuracy of the training data is 0.97767174243927
# 331
# The accuracy of the training data is 0.9784189462661743
# 332
# The accuracy of the training data is 0.9787924885749817
# 333
# The accuracy of the training data is 0.9788212180137634
# 334
# The accuracy of the training data is 0.9785051345825195
# 335
# The accuracy of the training data is 0.9781315326690674
# 336
# The accuracy of the training data is 0.9792810082435608
# 337
# The accuracy of the training data is 0.9788786768913269
# 338
# The accuracy of the training data is 0.9791085720062256
# 339
# The accuracy of the training data is 0.979252278804779
# 340
# The accuracy of the training data is 0.9778154492378235
# 341
# The accuracy of the training data is 0.9793384671211243
# 342
# The accuracy of the training data is 0.9804879426956177
# 343
# The accuracy of the training data is 0.9798269867897034
# 344
# The accuracy of the training data is 0.9784189462661743
# 345
# The accuracy of the training data is 0.9806603789329529
# 346
# The accuracy of the training data is 0.9798557162284851
# 347
# The accuracy of the training data is 0.9783326983451843
# 348
# The accuracy of the training data is 0.9789649248123169
# 349
# The accuracy of the training data is 0.9791373610496521
# 350
# The accuracy of the training data is 0.9791948199272156
# 351
# The accuracy of the training data is 0.9797120690345764
# 352
# The accuracy of the training data is 0.9790798425674438
# 353
# The accuracy of the training data is 0.9805166721343994
# 354
# The accuracy of the training data is 0.9798845052719116
# 355
# The accuracy of the training data is 0.9794821739196777
# 356
# The accuracy of the training data is 0.9804304838180542
# 357
# The accuracy of the training data is 0.9818097949028015
# 358
# The accuracy of the training data is 0.9813787937164307
# 359
# The accuracy of the training data is 0.9813212752342224
# 360
# The accuracy of the training data is 0.9821259379386902
# 361
# The accuracy of the training data is 0.9814075231552124
# 362
# The accuracy of the training data is 0.9804879426956177
# 363
# The accuracy of the training data is 0.9824707508087158
# 364
# The accuracy of the training data is 0.9824132919311523
# 365
# The accuracy of the training data is 0.9812063574790955
# 366
# The accuracy of the training data is 0.9818673133850098
# 367
# The accuracy of the training data is 0.9822983145713806
# 368
# The accuracy of the training data is 0.9822408556938171
# 369
# The accuracy of the training data is 0.9817810654640198
# 370
# The accuracy of the training data is 0.9816086888313293
# 371
# The accuracy of the training data is 0.9820972084999084
# 372
# The accuracy of the training data is 0.9826144576072693
# 373
# The accuracy of the training data is 0.9831891655921936
# 374
# The accuracy of the training data is 0.9825569987297058
# 375
# The accuracy of the training data is 0.9831317067146301
# 376
# The accuracy of the training data is 0.9825569987297058
# 377
# The accuracy of the training data is 0.9820109605789185
# 378
# The accuracy of the training data is 0.9834190607070923
# 379
# The accuracy of the training data is 0.9835052490234375
# 380
# The accuracy of the training data is 0.9835914969444275
# 381
# The accuracy of the training data is 0.9845685362815857
# 382
# The accuracy of the training data is 0.9842811822891235
# 383
# The accuracy of the training data is 0.9840225577354431
# 384
# The accuracy of the training data is 0.9835914969444275
# 385
# The accuracy of the training data is 0.983648955821991
# 386
# The accuracy of the training data is 0.9837064146995544
# 387
# The accuracy of the training data is 0.9842811822891235
# 388
# The accuracy of the training data is 0.9842236638069153
# 389
# The accuracy of the training data is 0.9839363098144531
# 390
# The accuracy of the training data is 0.9843099117279053
# 391
# The accuracy of the training data is 0.9845972657203674
# 392
# The accuracy of the training data is 0.9850570559501648
# 393
# The accuracy of the training data is 0.9847697019577026
# 394
# The accuracy of the training data is 0.9844248294830322
# 395
# The accuracy of the training data is 0.9843673706054688
# 396
# The accuracy of the training data is 0.9838788509368896
# 397
# The accuracy of the training data is 0.9848558902740479
# 398
# The accuracy of the training data is 0.9848271608352661
# 399
# The accuracy of the training data is 0.9839363098144531
# 400
# The accuracy of the training data is 0.9854018688201904
# 401
# The accuracy of the training data is 0.9851719737052917
# 402
# The accuracy of the training data is 0.9839650392532349
# 403
# The accuracy of the training data is 0.9846259951591492
# 404
# The accuracy of the training data is 0.9850857853889465
# 405
# The accuracy of the training data is 0.9833616018295288
# 406
# The accuracy of the training data is 0.9849420785903931
# 407
# The accuracy of the training data is 0.985947847366333
# 408
# The accuracy of the training data is 0.9837351441383362
# 409
# The accuracy of the training data is 0.985947847366333
# 410
# The accuracy of the training data is 0.986034095287323
# 411
# The accuracy of the training data is 0.9831317067146301
# 412
# The accuracy of the training data is 0.9861202836036682
# 413
# The accuracy of the training data is 0.9860915541648865
# 414
# The accuracy of the training data is 0.9851719737052917
# 415
# The accuracy of the training data is 0.9869536757469177
# 416
# The accuracy of the training data is 0.9864938855171204
# 417
# The accuracy of the training data is 0.9854305982589722
# 418
# The accuracy of the training data is 0.985947847366333
# 419
# The accuracy of the training data is 0.9856892228126526
# 420
# The accuracy of the training data is 0.9857179522514343
# 421
# The accuracy of the training data is 0.9861202836036682
# 422
# The accuracy of the training data is 0.9869248867034912
# 423
# The accuracy of the training data is 0.9866662621498108
# 424
# The accuracy of the training data is 0.9868674278259277
# 425
# The accuracy of the training data is 0.9871835112571716
# 426
# The accuracy of the training data is 0.9868961572647095
# 427
# The accuracy of the training data is 0.9868674278259277
# 428
# The accuracy of the training data is 0.9872123003005981
# 429
# The accuracy of the training data is 0.9871547818183899
# 430
# The accuracy of the training data is 0.9871547818183899
# 431
# The accuracy of the training data is 0.9874134063720703
# 432
# The accuracy of the training data is 0.9868674278259277
# 433
# The accuracy of the training data is 0.986838698387146
# 434
# The accuracy of the training data is 0.9872410297393799
# 435
# The accuracy of the training data is 0.9878157377243042
# 436
# The accuracy of the training data is 0.987643301486969
# 437
# The accuracy of the training data is 0.9877582788467407
# 438
# The accuracy of the training data is 0.9878731966018677
# 439
# The accuracy of the training data is 0.9873846769332886
# 440
# The accuracy of the training data is 0.9873272180557251
# 441
# The accuracy of the training data is 0.9881030917167664
# 442
# The accuracy of the training data is 0.9879881739616394
# 443
# The accuracy of the training data is 0.9878157377243042
# 444
# The accuracy of the training data is 0.9879019260406494
# 445
# The accuracy of the training data is 0.9877008199691772
# 446
# The accuracy of the training data is 0.9880743622779846
# 447
# The accuracy of the training data is 0.9880456328392029
# 448
# The accuracy of the training data is 0.9885054230690002
# 449
# The accuracy of the training data is 0.9887640476226807
# 450
# The accuracy of the training data is 0.9884766936302185
# 451
# The accuracy of the training data is 0.9887065887451172
# 452
# The accuracy of the training data is 0.9881605505943298
# 453
# The accuracy of the training data is 0.9878157377243042
# 454
# The accuracy of the training data is 0.9879307150840759
# 455
# The accuracy of the training data is 0.9882180690765381
# 456
# The accuracy of the training data is 0.988534152507782
# 457
# The accuracy of the training data is 0.9886490702629089
# 458
# The accuracy of the training data is 0.9882467985153198
# 459
# The accuracy of the training data is 0.9882755279541016
# 460
# The accuracy of the training data is 0.9886778593063354
# 461
# The accuracy of the training data is 0.9889652132987976
# 462
# The accuracy of the training data is 0.9882467985153198
# 463
# The accuracy of the training data is 0.9888215065002441
# 464
# The accuracy of the training data is 0.9891088604927063
# 465
# The accuracy of the training data is 0.9886778593063354
# 466
# The accuracy of the training data is 0.9884766936302185
# 467
# The accuracy of the training data is 0.9887065887451172
# 468
# The accuracy of the training data is 0.9890801310539246
# 469
# The accuracy of the training data is 0.9882180690765381
# 470
# The accuracy of the training data is 0.9887640476226807
# 471
# The accuracy of the training data is 0.9893100261688232
# 472
# The accuracy of the training data is 0.9884766936302185
# 473
# The accuracy of the training data is 0.9891088604927063
# 474
# The accuracy of the training data is 0.989338755607605
# 475
# The accuracy of the training data is 0.9888502359390259
# 476
# The accuracy of the training data is 0.9891663789749146
# 477
# The accuracy of the training data is 0.989223837852478
# 478
# The accuracy of the training data is 0.9887353181838989
# 479
# The accuracy of the training data is 0.989425003528595
# 480
# The accuracy of the training data is 0.9895686507225037
# 481
# The accuracy of the training data is 0.9896261096000671
# 482
# The accuracy of the training data is 0.9900858998298645
# 483
# The accuracy of the training data is 0.9898272752761841
# 484
# The accuracy of the training data is 0.9896548986434937
# 485
# The accuracy of the training data is 0.9897123575210571
# 486
# The accuracy of the training data is 0.9897698163986206
# 487
# The accuracy of the training data is 0.9897985458374023
# 488
# The accuracy of the training data is 0.9900571703910828
# 489
# The accuracy of the training data is 0.9903157949447632
# 490
# The accuracy of the training data is 0.9897123575210571
# 491
# The accuracy of the training data is 0.9898560047149658
# 492
# The accuracy of the training data is 0.9898847937583923
# 493
# The accuracy of the training data is 0.9901721477508545
# 494
# The accuracy of the training data is 0.9902583360671997
# 495
# The accuracy of the training data is 0.9904020428657532
# 496
# The accuracy of the training data is 0.9903733134269714
# 497
# The accuracy of the training data is 0.9901434183120728
# 498
# The accuracy of the training data is 0.9902870655059814
# 499
# The accuracy of the training data is 0.9903445243835449
# 500
# The accuracy of the training data is 0.9902008771896362
# 501
# The accuracy of the training data is 0.9903445243835449
# 502
# The accuracy of the training data is 0.9905169606208801
# 503
# The accuracy of the training data is 0.9905744194984436
# 504
# The accuracy of the training data is 0.9903445243835449
# 505
# The accuracy of the training data is 0.9910629391670227
# 506
# The accuracy of the training data is 0.9908905625343323
# 507
# The accuracy of the training data is 0.9898272752761841
# 508
# The accuracy of the training data is 0.990919291973114
# 509
# The accuracy of the training data is 0.990833044052124
# 510
# The accuracy of the training data is 0.9903445243835449
# 511
# The accuracy of the training data is 0.9909480214118958
# 512
# The accuracy of the training data is 0.991034209728241
# 513
# The accuracy of the training data is 0.9908043146133423
# 514
# The accuracy of the training data is 0.9905169606208801
# 515
# The accuracy of the training data is 0.9910054802894592
# 516
# The accuracy of the training data is 0.9908618330955505
# 517
# The accuracy of the training data is 0.990833044052124
# 518
# The accuracy of the training data is 0.9908905625343323
# 519
# The accuracy of the training data is 0.9906319379806519
# 520
# The accuracy of the training data is 0.9909767508506775
# 521
# The accuracy of the training data is 0.9913790822029114
# 522
# The accuracy of the training data is 0.9915227293968201
# 523
# The accuracy of the training data is 0.9912641048431396
# 524
# The accuracy of the training data is 0.9915514588356018
# 525
# The accuracy of the training data is 0.9912066459655762
# 526
# The accuracy of the training data is 0.9912928342819214
# 527
# The accuracy of the training data is 0.9912641048431396
# 528
# The accuracy of the training data is 0.9914365410804749
# 529
# The accuracy of the training data is 0.9914078116416931
# 530
# The accuracy of the training data is 0.9914365410804749
# 531
# The accuracy of the training data is 0.9920399785041809
# 532
# The accuracy of the training data is 0.9916951656341553
# 533
# The accuracy of the training data is 0.9913790822029114
# 534
# The accuracy of the training data is 0.9912928342819214
# 535
# The accuracy of the training data is 0.9917526245117188
# 536
# The accuracy of the training data is 0.9914652705192566
# 537
# The accuracy of the training data is 0.991120457649231
# 538
# The accuracy of the training data is 0.9920687079429626
# 539
# The accuracy of the training data is 0.9922411441802979
# 540
# The accuracy of the training data is 0.9919537901878357
# 541
# The accuracy of the training data is 0.9918100833892822
# 542
# The accuracy of the training data is 0.9918100833892822
# 543
# The accuracy of the training data is 0.9919825196266174
# 544
# The accuracy of the training data is 0.9918963313102722
# 545
# The accuracy of the training data is 0.9922698736190796
# 546
# The accuracy of the training data is 0.9920112490653992
# 547
# The accuracy of the training data is 0.9917526245117188
# 548
# The accuracy of the training data is 0.9920687079429626
# 549
# The accuracy of the training data is 0.9925860166549683
# 550
# The accuracy of the training data is 0.9922411441802979
# 551
# The accuracy of the training data is 0.9915514588356018
# 552
# The accuracy of the training data is 0.9918963313102722
# 553
# The accuracy of the training data is 0.9922411441802979
# 554
# The accuracy of the training data is 0.9915801882743835
# 555
# The accuracy of the training data is 0.9922698736190796
# 556
# The accuracy of the training data is 0.9926722049713135
# 557
# The accuracy of the training data is 0.9919537901878357
# 558
# The accuracy of the training data is 0.9924135804176331
# 559
# The accuracy of the training data is 0.992729663848877
# 560
# The accuracy of the training data is 0.9910916686058044
# 561
# The accuracy of the training data is 0.991723895072937
# 562
# The accuracy of the training data is 0.9929308295249939
# 563
# The accuracy of the training data is 0.9899997115135193
# 564
# The accuracy of the training data is 0.9918676018714905
# 565
# The accuracy of the training data is 0.993218183517456
# 566
# The accuracy of the training data is 0.9902583360671997
# 567
# The accuracy of the training data is 0.9924423098564148
# 568
# The accuracy of the training data is 0.9924997687339783
# 569
# The accuracy of the training data is 0.99261474609375
# 570
# The accuracy of the training data is 0.9922411441802979
# 571
# The accuracy of the training data is 0.9930170178413391
# 572
# The accuracy of the training data is 0.9930458068847656
# 573
# The accuracy of the training data is 0.9924135804176331
# 574
# The accuracy of the training data is 0.9923273921012878
# 575
# The accuracy of the training data is 0.992729663848877
# 576
# The accuracy of the training data is 0.9929595589637756
# 577
# The accuracy of the training data is 0.9924710392951965
# 578
# The accuracy of the training data is 0.9929308295249939
# 579
# The accuracy of the training data is 0.9929595589637756
# 580
# The accuracy of the training data is 0.9930458068847656
# 581
# The accuracy of the training data is 0.9931319952011108
# 582
# The accuracy of the training data is 0.9933618903160095
# 583
# The accuracy of the training data is 0.9931032657623291
# 584
# The accuracy of the training data is 0.9928446412086487
# 585
# The accuracy of the training data is 0.9931607246398926
# 586
# The accuracy of the training data is 0.9935630559921265
# 587
# The accuracy of the training data is 0.9929021000862122
# 588
# The accuracy of the training data is 0.9927583932876587
# 589
# The accuracy of the training data is 0.9936492443084717
# 590
# The accuracy of the training data is 0.9934768080711365
# 591
# The accuracy of the training data is 0.9926434755325317
# 592
# The accuracy of the training data is 0.9933906197547913
# 593
# The accuracy of the training data is 0.9937929511070251
# 594
# The accuracy of the training data is 0.9933906197547913
# 595
# The accuracy of the training data is 0.9931894540786743
# 596
# The accuracy of the training data is 0.9932469129562378
# 597
# The accuracy of the training data is 0.993218183517456
# 598
# The accuracy of the training data is 0.992729663848877
# 599
# The accuracy of the training data is 0.9938216805458069
# The accuracy of the validation set is 0.9378684759140015
# The accuracy of the test set is 0.9259698987007141

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
from PIL import Image as pilImage
def PIL2array(img):
    r = np.array(img.getdata()).reshape(img.size[1], img.size[0], 3)
    return r.tolist()
test_image1 = pilImage.open('./WebImages/TestImage1.jpg')
test_image2 = pilImage.open('./WebImages/TestImage2.jpg')
test_image3 = pilImage.open('./WebImages/TestImage3.jpg')
test_image4 = pilImage.open('./WebImages/TestImage4.jpg')
test_image5 = pilImage.open('./WebImages/TestImage5.jpg')
correct_estimates=np.array([33, 3, 27, 28, 25])
input_images = [test_image1, test_image2, test_image3, test_image4, test_image5]
f, plots = plt.subplots(1, len(input_images))
for i, image in enumerate(input_images):
    plots[i].imshow(image)
    plots[i].set_xticks([], [])
    plots[i].set_yticks([], [])
plt.show()

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.
test_images = input_images[:]
for i in range(len(test_images)):
    test_images[i]= PIL2array(test_images[i].resize((32,32),pilImage.ANTIALIAS))
test_images=np.array(test_images)
test_images=rgb2gray(test_images)
test_images=test_images-128/128
with tf.Session() as sess:
    saver.restore(sess, model_file)
    final_output = sess.run(selected_class, feed_dict={x: test_images, keep_prob: 1})
import csv
with open('signnames.csv') as csvfile:
    reader=csv.DictReader(csvfile)
    signNames={int(row['ClassId']):row['SignName'] for row in reader}
f, plots = plt.subplots(len(input_images)//2+1,2)
for i, image in enumerate(input_images):
    plots[i//2][i%2].imshow(image)
    plots[i//2][i%2].set_title(signNames[final_output[i]])
    plots[i//2][i%2].set_xticks([], [])
    plots[i//2][i%2].set_yticks([], [])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from ./final_model.ckpt

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.
final_output=np.array(final_output)
final_test_accuracy = np.average(final_output==correct_estimates)
print("The accuracy of detecting images from the web is {}".format(final_test_accuracy))
# Out:
# The accuracy of detecting images from the web is 0.8

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.
with tf.Session() as sess:
    saver.restore(sess, model_file)
    final_top_5 = sess.run(top_5,feed_dict={x:test_images, keep_prob:1})
final_top_5_strings=['']*len(final_top_5.values)
for i in range(len(final_top_5.values)):
    string_i=""
    for value, index in zip(final_top_5.values[i], final_top_5.indices[i]):
        string_i+=signNames[index]+": "+ str(value)+"\n"
    final_top_5_strings[i]=string_i
#f, plots = plt.subplots(len(input_images),1)
for i, image in enumerate(input_images):
    plt.figure()
    plt.imshow(image)
    plt.title("Figure {}".format(i))
    print("The expectations of figure {} is:\n {}".format(i,final_top_5_strings[i]))
    #plots[i].set_title(final_top_5_strings[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from ./final_model.ckpt
# The expectations of figure 0 is:
#  Turn right ahead: 1.0
# Keep left: 4.09547e-28
# Speed limit (20km/h): 0.0
# Speed limit (30km/h): 0.0
# Speed limit (50km/h): 0.0
#
# The expectations of figure 1 is:
#  Speed limit (50km/h): 1.0
# Speed limit (20km/h): 0.0
# Speed limit (30km/h): 0.0
# Speed limit (60km/h): 0.0
# Speed limit (70km/h): 0.0
#
# The expectations of figure 2 is:
#  Pedestrians: 1.0
# Speed limit (20km/h): 0.0
# Speed limit (30km/h): 0.0
# Speed limit (50km/h): 0.0
# Speed limit (60km/h): 0.0
#
# The expectations of figure 3 is:
#  Children crossing: 1.0
# Speed limit (20km/h): 0.0
# Speed limit (30km/h): 0.0
# Speed limit (50km/h): 0.0
# Speed limit (60km/h): 0.0
#
# The expectations of figure 4 is:
#  Road work: 1.0
# Speed limit (20km/h): 0.0
# Speed limit (30km/h): 0.0
# Speed limit (50km/h): 0.0
# Speed limit (60km/h): 0.0

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
